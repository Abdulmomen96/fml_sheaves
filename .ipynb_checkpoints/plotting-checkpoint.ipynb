# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
rel_err_dfed = np.load('relative_error_dfedu.npy').ravel()
rel_err_sheave_fml = np.load('relative_error_sheave_fml.npy').ravel()

# %%
plt.semilogy(rel_err_dfed, label='dFedU') # dFedU
plt.xlabel('Number of Iterations') # Federated Sheaves
plt.ylabel('Optimality Gap')
legend = plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.grid(True)
plt.savefig("Optimality Gap.pdf")
plt.ylim([10**(-5),0.5])
# Out:
# (1e-05, 0.5)
